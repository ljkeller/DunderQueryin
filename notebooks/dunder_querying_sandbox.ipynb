# %%
from fastai.tabular.all import *

pd.options.display.max_rows = 20
pd.options.display.max_columns = 8
# %config InteractiveShell.ast_node_interactivity='last_expr_or_assign'

# %%
raw_data_path = '../data/raw_office_dialog.csv'
df = pd.read_csv(raw_data_path, encoding='unicode-escape')
# Out:
#           id  season  episode  scene  \
# 0          1       1        1      1
# 1          2       1        1      1
# 2          3       1        1      1
# 3          4       1        1      1
# 4          5       1        1      1
# ...      ...     ...      ...    ...
# 59904  59905       9       23    112
# 59905  59906       9       23    113
# 59906  59907       9       23    114
# 59907  59908       9       23    115
# 59908  59909       9       23    116
#
#                                                                                                                                                                                                                                                                                                                    line_text  \
# 0                                                                                                                                                                                                                                             All right Jim. Your quarterlies look very good. How are things at the library?
# 1                                                                                                                                                                                                                                                                                 Oh, I told you. I couldn't close it. So...
# 2                                                                                                                                                                                                                                        So you've come to the master for guidance? Is this what you're saying, grasshopper?
# 3                                                                                                                                                                                                                                                                                 Actually, you called me in here, but yeah.
# 4                                                                                                                                                                                                                                                                            All right. Well, let me show you how it's done.
# ...                                                                                                                                                                                                                                                                                                                      ...
# 59904  It all seems so very arbitrary. I applied for a job at this company because they were hiring. I took a desk at the back because it was empty. But'[chuckles] no matter how you get there or where you end up, human beings have this miraculous gift to make that place home. [standing with two cops] Let's do this.
# 59905                                                                                                           I just feel lucky that I got a chance to share my crummy story with anyone out there who thinks they're the only one to take a dump in a paper shredder. You're not alone sister. Let's get a beer sometime.
# 59906                                                                                                                                                           I'm happy that this was all filmed so I can remember everyone and what we did. I worked for a paper company all these years and I never wrote anything down.
# 59907                                                           I sold paper at this company for 12 years. My job was to speak to clients on the phone about quantities and types of copier paper. Even if I didn't love every minute of it, everything I have, I owe to this job. This stupid,wonderful,boring,amazing job.
# 59908                                                                 I thought it was weird when you picked us to make a documentary. But all in all I think an ordinary paper company like Dunder Mifflin was a great subject for a documentary. There's a lot of beauty in ordinary things. Isn't that kind of the point?
#
#         speaker  deleted
# 0       Michael    False
# 1           Jim    False
# 2       Michael    False
# 3           Jim    False
# 4       Michael    False
# ...         ...      ...
# 59904     Creed    False
# 59905  Meredith    False
# 59906   Phyllis    False
# 59907       Jim    False
# 59908       Pam    False
#
# [59909 rows x 7 columns]

# %%
speakers = df['speaker'].unique()
# Out:
# array(['Michael', 'Jim', 'Pam', 'Dwight', 'Jan', 'Todd Packer', 'Phyllis',
#        'Stanley', 'Oscar', 'Angela', 'Kevin', 'Ryan', 'Man', 'Roy',
#        'Documentary Crew Member', 'Mr. Brown', 'Toby', 'Kelly',
#        'Meredith', 'Travel Agent', 'Man on Phone', 'Everybody', 'Lonny',
#        'Darryl', 'Teammates', 'Michael and Dwight', 'Warehouse worker',
#        'Madge', 'Worker', 'Packer', 'Warehouse Worker', 'Katy',
#        'Guy at bar', 'Other Guy at Bar', 'Guy At Bar', 'Pam and Jim',
#        'Employee', "Chili's Employee", 'Waitress', 'Manager',
#        "Kevin's computer", 'Warehouse Guy', 'Warehouse guy',
#        'Warehouse guys', 'Video', 'Man in Video', 'Actor',
#        'Redheaded Actress', "Mr. O'Malley", 'Albiny', "Pam's Mom",
#        'Carol', 'Bill', 'Everyone', 'Crowd', 'song', 'Song',
#        'Dwight and Michael', 'Sherri', 'Creed', 'Devon', 'Children',
#        'Kid', 'Vance Refrigeration Worker #1',
#        'Vance Refrigeration Worker #2', 'Hank the Security Guard', 'Ira',
#        "Ryan's Voicemail", 'Master', 'Alyssa', 'Christian', 'Hostess',
#        'Michael and Christian', 'Sadiq (IT guy)', 'Mark',
#        'Improv Teacher', 'Mary-Beth', 'Girl acting Pregnant', 'Actress',
#        'Michael and Jim', 'Kevin & Oscar', 'All', 'Liquor Store Clerk',
#        'JIm', 'Bob Vance', 'Phyllis, Meredith, Michael, Kevin',
#        'Captain Jack', 'Brenda', 'Darryl and Katy', 'Jim and Pam',
#        'Billy Merchant', 'Doctor', 'Lab Tech', 'Dana', "Hooter's Girls",
#        'Phylis', 'Gil', 'Pam and others', 'Ed', 'Todd', "Jim's voicemail",
#        'Women', 'Guy', 'Men', 'Group chant', 'All the Men',
#        'Dwight and Roy', 'Delivery man', 'Craig', 'Josh', 'David', 'Dan',
#        'Receptionist', 'Overhead', 'Speaker', 'Jim and Dwight', 'Melissa',
#        'Sasha', 'Abby', 'Jake', 'The Kids', 'Kids', 'Miss Trudy',
#        'Edward R. Meow', 'Chet', 'Young Michael', 'Delivery Woman',
#        'Delivery Boy', 'Office Staff', 'Store Employee', 'Pam/Jim',
#        'Linda', 'Hank', 'Sheriff', 'I.D. Photographer', 'Photographer',
#        'Anglea', 'Female worker', "Billy's Girlfriend", 'Billy', 'Dealer',
#        'Bob', "Meredith's Vet", 'Andy', 'Karen', 'Jerome Bettis', 'Ted',
#        'Waiter', 'Jim, Josh, and Dwight', 'Evan', 'Alan',
#        'Ryan and others', 'Hannah', 'Announcer', 'Pretzel guy',
#        'Cousin Mose', 'Tony', 'Server', 'Girls', "Kelly's Mom",
#        "Kelly's Father", 'Young Man', 'Andy and Jim', 'Mrs. Kapoor',
#        'Mr. Kapoor', 'Dwight ', 'M ichael', 'Michael ', 'Martin',
#        'Male voice', 'Michael & Dwight', 'Andy & Michael', 'Chef',
#        'Woman at bar', 'Cindy', 'Second Cindy', 'Other waitress',
#        'Andy and Michael', 'Both', 'Someone', 'Harvey', 'Buyer', 'Kenny',
#        'Julius', 'Phone', 'Staples Guy', 'MIchael', 'Lady', 'Paris',
#        'Marcy', 'Ben Franklin', 'Elizabeth', 'Priest', 'Uncle Al',
#        'Randy', 'Unknown', 'College Student', 'Business Student #1',
#        'Business Student #2', 'Business Student #3', 'Woman', 'Artist',
#        'Student 1', 'Student 2', 'Student 3', 'Rachel', 'Dan Gore',
#        'Bartender', 'Child', 'Hunter', 'Larry', 'Chad Lite', 'Jamie',
#        'Barbara', 'School Official', 'Barbara Allen', 'Spanish Teacher',
#        'Denise', 'Group', 'IT Tech Guy', 'Nurse', 'Intern',
#        'Pediatrician', 'Robert Dunder', 'Amy', 'GPS', 'Larry Myers',
#        'Ex-client', 'Voice of Thomas Dean', 'sAndy', 'DunMiff/sys',
#        'DwightKSchrute', 'Tech Guy', 'Angels', 'Pizza guy',
#        'Voice #1 on phone', 'Voice #2 on phone', 'Nick', 'Mose',
#        'Co-Worker 1', 'Stanely', 'Vikram', 'Co-Worker 2', 'Co-Worker 3',
#        'Mr. Figaro', 'Oscar and Stanley', 'Ad guy 1', 'Ad guy 2',
#        'David Wallace', 'Andy, Creed, Kevin, Kelly, Darryl',
#        'Andy, Creed, Kevin, Kelly', "Michael's Ad", 'Rolando', 'Ben',
#        'Security guard', 'Lester', 'Diane Kelly', 'Diane',
#        'Deposition Reporter', 'Council', "Hunter's CD", 'Michae',
#        'Officer 1', 'Officer 2', 'Officer', 'Neighbor',
#        "Wendy's phone operator", 'Margaret', 'Coffee shop worker',
#        'Jan [on phone]', 'W.B. Jones', 'Paul Faust', 'Bill Cress', 'Paul',
#        'Michael/Dwight', 'Troy', 'Girl in Club', 'Tall Girl #1',
#        'All Girls', 'Tall Girl #2', 'Girl in 2nd club', 'Cleaning lady',
#        'Michael and Darryl', 'Phil Maguire', 'Phil', 'Justin',
#        'Angela and Dwight', 'Maguire', 'Woman on mic', 'Graphics guy',
#        'Brad', 'Air Force recruiter', 'Holly', 'Woman over speakerphone',
#        'Vance Refrigeration guy', 'Co-workers', 'Ronnie', 'Professor',
#        'Friend', 'JIM9334 [screen name]', 'Receptionitis15 [screen name]',
#        'JIM9334', 'Receptionitis15', 'Micheal', 'Michael & Holly',
#        'Kendall', 'Michael [on phone]', 'Pam [on phone]', 'Man on phone',
#        'Hank [the security guard]', 'Guy in audience',
#        'Michael and Holly', 'Michael, Holly, and Darryl', 'Tom', 'Pete',
#        'Holly & Darryl', 'Holly & Michael', 'Mother', 'Alex', 'Customer',
#        'Kevin & Andy', 'Stanley & Phyllis', 'Stewardess', 'Beth',
#        'Concierge', 'Marie', 'Guy at table', 'Concierge Marie', 'Client',
#        'Dacvid Walalce', 'David Wallce', 'Dacvid Wallace', 'Leo',
#        'Vance Refrigeration Guy', 'Police Officer 1', 'Police Officer 2',
#        'Guy buying doll', 'Rehab Nurse', 'Everyone watching',
#        'Entire Prince family', 'Prince Grandfather', 'Entire office',
#        'Jim ', 'Prince', 'Prince Granddaughter', 'Prince Grandmother',
#        'Prince Son', 'Phyllis and Creed', 'Lawyer', 'Michel',
#        'CPR trainer', 'CPR Trainer', 'Rose', 'Jessica Alba', 'Lily',
#        'Sam', 'Warehouse Michael', 'Julia', 'A.J.', 'Phone Salesman',
#        'Jim, Pam, Michael and Dwight', 'Blood Drive Worker', 'Blood Girl',
#        'Lynn', 'Blonde', 'Eric', 'Girl', 'Charles', 'Stephanie',
#        'Employees', 'Isaac', 'Angela and Kelly', 'Supervisor', 'Michal',
#        'Nana', 'Chares', 'Old Woman', 'Erin', 'Dwight and Erin',
#        'Dwight and Andy', 'Michael, Pam & Ryan', 'Secretary',
#        'Automated phone voice', 'Mr. Schofield', 'Financial Guy', 'Ty',
#        'Jessica', 'Vance Refrigeration Guy 1',
#        'Vance Refrigeration Guy 2', 'VRG 1', 'VRG 2', 'Rolph', 'AJ',
#        'Man from Buffalo', 'Woman from Buffalo', 'Dwight & Andy',
#        'Female Intern', 'Female intern', 'Maurie', 'Dwight, Jim & Pam',
#        'Jim & Pam', 'Megan', 'Gwenneth', 'Front Desk Clerk',
#        'Mr. Halpert', 'Mema', 'Mr. Beesly', 'Little Girl', 'Penny',
#        'Isabelle', 'Hotel Employee', 'Hotel Manager', "Pam's mom",
#        'Tom Halpert', 'Pete Halpert', 'Tom and Pete', "Pam's dad",
#        'Grotti', 'Andy and Dwight', 'Credit card rep', 'Rep', 'Various',
#        'Keena Gifford', 'Helene', "David Wallace's Secretary",
#        'Voice on CD player', 'Limo Driver', 'Laurie', 'Registrar',
#        'Security', 'Woman in line', 'Man in line', 'Shareholder',
#        'Female Shareholder', 'Second Shareholder', 'Third Shareholder',
#        'Fourth Shareholder', "O'Keefe", 'Mikela', 'Students', 'Teacher',
#        'Lefevre', 'Zion', 'Deliveryman', 'Michael and Erin', 'Office',
#        'Kelly and Erin', 'Matt', 'Computron', 'Fake Stanley', 'Gabe',
#        'Andy & Erin', 'Christian Slater', 'Jo Bennett', 'Jo', 'Jerry',
#        'Teddy Wallace', 'Mrs. Wallace', 'Teddy',
#        'Dwight, Jim and Michael', 'Policeman', 'Hospital employee',
#        "(Pam's mom) Heleen", 'Kathy', 'Dale', 'Clark', 'D',
#        'Warehouse guy 1', 'Warehouse guy 2', 'Reid',
#        'Night cleaning crew', 'Meredith, Creed, Oscar and Matt',
#        'Miichael', 'Julie', 'Hide', 'Bar Manager', 'Bouncer',
#        'Girl at table', 'Cookie Monster', "Hayworth's waiter",
#        "Oscar's voice from the computer", 'Donna', 'Michael and Donna',
#        'Mihael', 'Old lady', 'Glen', 'Gym Instructor', 'Gym instructor',
#        'Dwight and Angela', 'Shane', 'Reporter', 'Realtor', 'Luke',
#        'Window treatment guy', 'Angel', 'Salesman', 'Usher', 'Shelby',
#        'Sweeney Todd', 'Mexican Man', 'Son', 'Nate',
#        'Employees except Dwight', 'Astrid', 'Carroll', 'Carrol', 'Danny',
#        'Steve', 'Darryl and Andy', 'Church congregation', 'Pastor',
#        'Female church member', 'Male church member',
#        'Female church member [to Michael]', 'Doug [church member]',
#        'Doug', 'Mee-Maw', 'MeeMaw', 'Carla', "Jim's Dad", 'Bus driver',
#        'Michael and Andy', 'Another guy', 'Radio', 'Cece', 'TV',
#        'Meridith', 'Robotic Voice', 'Ryan and Michael', 'Phyliss',
#        'Dwight & Nate', 'Passer-by', 'Pam ', 'Bass Player', 'Justine',
#        'Jada', 'Robert', 'Darrly', 'Member', 'Video Michael',
#        'Bookstore employee', 'DJ', 'David Brent', 'Older guy',
#        'Phyllis, Stanley, Dwight', 'Younger Guy', 'Older Woman',
#        'Professor Powell', 'Ryan and Kelly', 'Helen', 'Attendant',
#        'Hot Dog Guy', 'Cell Phone Sales Person', 'Boom Box',
#        'Andy and Erin', 'Holy', "Holly's Mom", "Holly's Dad", 'Deangelo',
#        'Deangelo/Michael', "Darryl's sister", 'DeAngelo', 'Audience',
#        'Together', 'Erin and Kelly', 'abe', 'Rory', 'Jordan',
#        'Dwight [on phone]', 'Mose [on phone]', 'All but Oscar',
#        'Darryl and Angela', 'Fred Henry', 'Fred', 'Warren Buffett',
#        'Warren', 'Robert California', 'Merv Bronte', 'Merv',
#        'Nellie Bertram', 'Nellie', 'Finger Lakes Guy',
#        'Pam as fourth-biggest client', 'Pam as ninth-biggest client',
#        'Darryl & Oscar', 'Tattoo Artist', 'Female Applicant',
#        'Male Applicant 1', 'Male Applicant 2', 'Gideon', 'Bruce',
#        'Dwight, Erin, Jim & Kevin', 'Walter', 'Ellen', 'Walter Jr',
#        'Andy & Walter', 'Walter & Walter Jr', "Erin's Cell Phone", 'Bert',
#        'Gabe/Kelly/Toby', 'Andy/Pam', 'Andy/Stanley', 'Val',
#        'Warehouse Crew', 'Cathy', 'Offscreen', 'Curtis', 'Drummer',
#        'Pam and Kelly', 'Old Man', 'Andy and Darryl', 'Darryl and Kevin',
#        'Park Ranger', 'Chelsea', 'Archivist', 'Narrator', 'Soldier',
#        'Amanda', 'Susan', 'Andy/Oscar', "Bob's Secretary",
#        'Mrs. California', 'Host', 'Queerenstein Bears', "Oscar's friend",
#        'Stu', 'Stonewall Host', 'Meredith & Kelly', 'Einsteins',
#        'Senator Lipton', 'Ernesto', 'Officer Foley',
#        'Andy, Darryl & Officer Foley', 'Saleswoman', 'Emergency Operator',
#        'Paramedic', 'Donna Muraski', 'Wally Amos', 'Angela/Pam',
#        'Brandon', 'Blogger', 'Blogger 2', 'Lady Blogger', 'Patty',
#        'Old Lady', 'Others', 'Elderly Woman', 'Irene', 'Alonzo', 'Glenn',
#        'Erin and Irene', 'Kevin & Meredith', 'Lauren', 'Party guests',
#        'Magician', 'Ravi', 'Robert & Creed', 'Wrangler', 'Senator', 'Vet',
#        'Harry', 'Mr. Ramish', 'Calvin', 'Off-camera', 'Rafe', 'Fake Jim',
#        'Voicemail', 'Nellie and Pam', 'Phyllis, Kevin & Stanley', 'HCT',
#        'HCT Member #1', 'HCT Member #2', 'Broccoli Rob', 'Businessman #1',
#        'Businessman #2', 'Businessman #3', 'HCT Member #3', 'White',
#        'Boat Guy', 'Walt Jr.', 'Senator Liptop', 'Guys in breakroom',
#        'Business partner', 'Molly', 'Colin', 'Trevor', 'Julius Irving',
#        'New Instant Message', 'Suit Store Father', 'Athlead Employee',
#        'Dennis', 'Wade', 'Suit Store Son', 'Female Athlead Employee',
#        '3rd Athlead Employee', '4th Athlead Employee', 'Co-worker',
#        'Co-worker #2', 'Mr. Romanko', 'Dance Teacher', 'Ballerinas',
#        'Parent in Audience', 'Parent in audience #2',
#        'Parent in audience #1', 'Investor', 'Lonnie', 'Fast Food Worker',
#        'Drive Thru Customer', 'Brian', 'Cameraman', 'Rolf', 'Gabor',
#        'Zeke', 'Melvina', 'Wolf', 'Sensei Ira', 'Pam & Dwight', 'Frank',
#        'Party Announcer', 'Party Guest', 'Party Photographer',
#        'Party Waiter', 'Nail stylist 1', 'Nail stylist 2', 'Nail manager',
#        'Shirley', 'Athlead Coworker', 'Roger', 'Alice',
#        "Oscar's Computer", 'Jeb', 'German Minister', 'Fannie', 'Henry',
#        'Esther', 'Aunt Shirley', 'Cameron', 'Promo Voice', 'Ryan Howard',
#        'Mr. Ruger', 'Promo Announcer', 'Ruger Sister 1', 'Salesmen',
#        'Ruger Sister 2', 'Angela & Oscar', 'Reporter #1', 'Reporter #2',
#        'Mrs. Davis', 'Phillip', 'Carla Fern', 'Director', 'Producer',
#        'Bob Vance, Vance Refrigeration', 'Production Assistant', 'Sensei',
#        'Philip', 'Check-in guy', 'Casey', 'Mark McGrath', 'Jim & Dwight',
#        'Camera Crew', 'People in line', 'Santigold', 'Aaron Rodgers',
#        'Clay Aiken', 'CameraMan', 'Malcolm', 'Casey Dean', 'Bill Hader',
#        'Seth Mayers', 'Dakota', 'Stripper', 'Jakey', 'Man 1', 'Woman 1',
#        'Woman 2', 'Man 2', 'Moderator', 'Man 3', 'Woman 3', 'Woman 4',
#        'Joan', 'Minister', 'Carol Stills'], dtype=object)

# %%
len(df['speaker'].unique())
# Out:
# 784

# %%
df['speaker'].value_counts()
# Out:
# Michael               12145
# Dwight                 7532
# Jim                    6814
# Pam                    5375
# Andy                   3969
#                       ...
# Michael and Erin          1
# Deliveryman               1
# Zion                      1
# Fourth Shareholder        1
# Carol Stills              1
# Name: speaker, Length: 784, dtype: int64

# %%
df_freq_by_speaker = df['speaker'].value_counts().to_frame()
# Out:
#                     speaker
# Michael               12145
# Dwight                 7532
# Jim                    6814
# Pam                    5375
# Andy                   3969
# ...                     ...
# Michael and Erin          1
# Deliveryman               1
# Zion                      1
# Fourth Shareholder        1
# Carol Stills              1
#
# [784 rows x 1 columns]

# %%
df_freq_by_speaker = df['speaker'].value_counts().to_frame().style.bar()
# Out:
# <style type="text/css">
# #T_6985c_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 100.0%, transparent 100.0%);
# }
# #T_6985c_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 62.0%, transparent 62.0%);
# }
# #T_6985c_row2_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 56.1%, transparent 56.1%);
# }
# #T_6985c_row3_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 44.3%, transparent 44.3%);
# }
# #T_6985c_row4_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 32.7%, transparent 32.7%);
# }
# #T_6985c_row5_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 14.1%, transparent 14.1%);
# }
# #T_6985c_row6_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 14.0%, transparent 14.0%);
# }
# #T_6985c_row7_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 12.3%, transparent 12.3%);
# }
# #T_6985c_row8_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 12.1%, transparent 12.1%);
# }
# #T_6985c_row9_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 11.4%, transparent 11.4%);
# }
# #T_6985c_row10_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 10.5%, transparent 10.5%);
# }
# #T_6985c_row11_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 8.8%, transparent 8.8%);
# }
# #T_6985c_row12_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 7.9%, transparent 7.9%);
# }
# #T_6985c_row13_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 7.8%, transparent 7.8%);
# }
# #T_6985c_row14_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 7.7%, transparent 7.7%);
# }
# #T_6985c_row15_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 6.3%, transparent 6.3%);
# }
# #T_6985c_row16_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 5.3%, transparent 5.3%);
# }
# #T_6985c_row17_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 5.0%, transparent 5.0%);
# }
# #T_6985c_row18_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 4.4%, transparent 4.4%);
# }
# #T_6985c_row19_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 3.8%, transparent 3.8%);
# }
# #T_6985c_row20_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 3.6%, transparent 3.6%);
# }
# #T_6985c_row21_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 3.5%, transparent 3.5%);
# }
# #T_6985c_row22_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 3.1%, transparent 3.1%);
# }
# #T_6985c_row23_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 2.8%, transparent 2.8%);
# }
# #T_6985c_row24_col0, #T_6985c_row25_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 2.1%, transparent 2.1%);
# }
# #T_6985c_row26_col0, #T_6985c_row27_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 1.8%, transparent 1.8%);
# }
# #T_6985c_row28_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 1.6%, transparent 1.6%);
# }
# #T_6985c_row29_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 1.4%, transparent 1.4%);
# }
# #T_6985c_row30_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 0.9%, transparent 0.9%);
# }
# #T_6985c_row31_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 0.8%, transparent 0.8%);
# }
# #T_6985c_row32_col0, #T_6985c_row33_col0, #T_6985c_row34_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 0.7%, transparent 0.7%);
# }
# #T_6985c_row35_col0, #T_6985c_row36_col0, #T_6985c_row37_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 0.6%, transparent 0.6%);
# }
# #T_6985c_row38_col0, #T_6985c_row39_col0, #T_6985c_row40_col0, #T_6985c_row41_col0, #T_6985c_row42_col0, #T_6985c_row43_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 0.5%, transparent 0.5%);
# }
# #T_6985c_row44_col0, #T_6985c_row45_col0, #T_6985c_row46_col0, #T_6985c_row47_col0, #T_6985c_row48_col0, #T_6985c_row49_col0, #T_6985c_row50_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 0.4%, transparent 0.4%);
# }
# #T_6985c_row51_col0, #T_6985c_row52_col0, #T_6985c_row53_col0, #T_6985c_row54_col0, #T_6985c_row55_col0, #T_6985c_row56_col0, #T_6985c_row57_col0, #T_6985c_row58_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 0.3%, transparent 0.3%);
# }
# #T_6985c_row59_col0, #T_6985c_row60_col0, #T_6985c_row61_col0, #T_6985c_row62_col0, #T_6985c_row63_col0, #T_6985c_row64_col0, #T_6985c_row65_col0, #T_6985c_row66_col0, #T_6985c_row67_col0, #T_6985c_row68_col0, #T_6985c_row69_col0, #T_6985c_row70_col0, #T_6985c_row71_col0, #T_6985c_row72_col0, #T_6985c_row73_col0, #T_6985c_row74_col0, #T_6985c_row75_col0, #T_6985c_row76_col0, #T_6985c_row77_col0, #T_6985c_row78_col0, #T_6985c_row79_col0, #T_6985c_row80_col0, #T_6985c_row81_col0, #T_6985c_row82_col0, #T_6985c_row83_col0, #T_6985c_row84_col0, #T_6985c_row85_col0, #T_6985c_row86_col0, #T_6985c_row87_col0, #T_6985c_row88_col0, #T_6985c_row89_col0, #T_6985c_row90_col0, #T_6985c_row91_col0, #T_6985c_row92_col0, #T_6985c_row93_col0, #T_6985c_row94_col0, #T_6985c_row95_col0, #T_6985c_row96_col0, #T_6985c_row97_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 0.2%, transparent 0.2%);
# }
# #T_6985c_row98_col0, #T_6985c_row99_col0, #T_6985c_row100_col0, #T_6985c_row101_col0, #T_6985c_row102_col0, #T_6985c_row103_col0, #T_6985c_row104_col0, #T_6985c_row105_col0, #T_6985c_row106_col0, #T_6985c_row107_col0, #T_6985c_row108_col0, #T_6985c_row109_col0, #T_6985c_row110_col0, #T_6985c_row111_col0, #T_6985c_row112_col0, #T_6985c_row113_col0, #T_6985c_row114_col0, #T_6985c_row115_col0, #T_6985c_row116_col0, #T_6985c_row117_col0, #T_6985c_row118_col0, #T_6985c_row119_col0, #T_6985c_row120_col0, #T_6985c_row121_col0, #T_6985c_row122_col0, #T_6985c_row123_col0, #T_6985c_row124_col0, #T_6985c_row125_col0, #T_6985c_row126_col0, #T_6985c_row127_col0, #T_6985c_row128_col0, #T_6985c_row129_col0, #T_6985c_row130_col0, #T_6985c_row131_col0, #T_6985c_row132_col0, #T_6985c_row133_col0, #T_6985c_row134_col0, #T_6985c_row135_col0, #T_6985c_row136_col0, #T_6985c_row137_col0, #T_6985c_row138_col0, #T_6985c_row139_col0, #T_6985c_row140_col0, #T_6985c_row141_col0, #T_6985c_row142_col0, #T_6985c_row143_col0, #T_6985c_row144_col0, #T_6985c_row145_col0, #T_6985c_row146_col0, #T_6985c_row147_col0, #T_6985c_row148_col0, #T_6985c_row149_col0, #T_6985c_row150_col0, #T_6985c_row151_col0, #T_6985c_row152_col0, #T_6985c_row153_col0, #T_6985c_row154_col0, #T_6985c_row155_col0, #T_6985c_row156_col0, #T_6985c_row157_col0, #T_6985c_row158_col0, #T_6985c_row159_col0, #T_6985c_row160_col0, #T_6985c_row161_col0, #T_6985c_row162_col0, #T_6985c_row163_col0, #T_6985c_row164_col0, #T_6985c_row165_col0, #T_6985c_row166_col0, #T_6985c_row167_col0, #T_6985c_row168_col0, #T_6985c_row169_col0, #T_6985c_row170_col0, #T_6985c_row171_col0, #T_6985c_row172_col0, #T_6985c_row173_col0, #T_6985c_row174_col0, #T_6985c_row175_col0, #T_6985c_row176_col0, #T_6985c_row177_col0, #T_6985c_row178_col0, #T_6985c_row179_col0, #T_6985c_row180_col0, #T_6985c_row181_col0, #T_6985c_row182_col0, #T_6985c_row183_col0, #T_6985c_row184_col0, #T_6985c_row185_col0, #T_6985c_row186_col0, #T_6985c_row187_col0, #T_6985c_row188_col0, #T_6985c_row189_col0, #T_6985c_row190_col0, #T_6985c_row191_col0, #T_6985c_row192_col0, #T_6985c_row193_col0, #T_6985c_row194_col0, #T_6985c_row195_col0, #T_6985c_row196_col0, #T_6985c_row197_col0, #T_6985c_row198_col0, #T_6985c_row199_col0, #T_6985c_row200_col0, #T_6985c_row201_col0, #T_6985c_row202_col0, #T_6985c_row203_col0, #T_6985c_row204_col0, #T_6985c_row205_col0, #T_6985c_row206_col0, #T_6985c_row207_col0, #T_6985c_row208_col0, #T_6985c_row209_col0, #T_6985c_row210_col0, #T_6985c_row211_col0, #T_6985c_row212_col0, #T_6985c_row213_col0, #T_6985c_row214_col0, #T_6985c_row215_col0, #T_6985c_row216_col0, #T_6985c_row217_col0, #T_6985c_row218_col0, #T_6985c_row219_col0, #T_6985c_row220_col0, #T_6985c_row221_col0, #T_6985c_r

# %%
df['speaker'].value_counts().head(30).plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# Now that we know there are 784 'speakers', and we have an idea of the frequency of each speaker, it could be useful to generate a few different datasets.
#
# Ideas:
# 1. Take top 30 speakers by value_counts arbitrarily (# lines really taper off)
# 2. Take only individuals, drop groups
# 3. Take top 10% speakers?

# %%
df['speaker'].value_counts().describe()
# Out:
# count      784.000000
# mean        76.414541
# std        630.450061
# min          1.000000
# 25%          1.000000
# 50%          3.000000
# 75%          9.000000
# max      12145.000000
# Name: speaker, dtype: float64

# %%
# df['speaker'].value_counts().quantile([0, .1], axis=1)
df_speaker_freq = df['speaker'].value_counts().to_frame().reset_index()
df_speaker_freq.columns = ['speaker', 'num_lines']

# %%
speakers_95th_percentile_df = df_speaker_freq[df_speaker_freq.num_lines > df_speaker_freq.num_lines.quantile(.95)]
# Out:
#         speaker  num_lines
# 0       Michael      12145
# 1        Dwight       7532
# 2           Jim       6814
# 3           Pam       5375
# 4          Andy       3969
# ..          ...        ...
# 35  Todd Packer         74
# 36          Val         73
# 37        Danny         68
# 38         Josh         64
# 39          All         62
#
# [40 rows x 2 columns]

# %%
speakers_21_df = df_speaker_freq[df_speaker_freq.num_lines > df_speaker_freq.num_lines.quantile(.9741)]
# Out:
#      speaker  num_lines
# 0    Michael      12145
# 1     Dwight       7532
# 2        Jim       6814
# 3        Pam       5375
# 4       Andy       3969
# ..       ...        ...
# 16  Meredith        645
# 17     Holly        609
# 18    Nellie        529
# 19     Creed        456
# 20      Gabe        436
#
# [21 rows x 2 columns]

# %%
from pathlib import Path
speakers_95th_percentile_path = Path('../data/speakers_95th_percentile.csv')

if not speakers_95th_percentile_path.is_file():
    speakers_95th_percentile_df.to_csv(speakers_95th_percentile_path, encoding='utf-8')

# %%
speakers_top_21_path = Path('../data/speakers_top_21.csv')

if not speakers_top_21_path.is_file():
    speakers_21_df.to_csv(speakers_top_21_path, encoding='utf-8')

# %%
ax = speakers_95th_percentile_df.plot(x='speaker', y='num_lines', kind='bar', figsize = (15, 7))
ax.set_title('95% Percentile Speakers')
ax.set_xlabel('Speaker')
ax.set_ylabel('Number of Lines')
# Out:
# Text(0, 0.5, 'Number of Lines')

# %%
unique_speakers_95th_percentile = set(speakers_95th_percentile_df['speaker'])
# Out:
# {'All',
#  'Andy',
#  'Angela',
#  'Carol',
#  'Charles',
#  'Clark',
#  'Creed',
#  'Danny',
#  'Darryl',
#  'David',
#  'David Wallace',
#  'DeAngelo',
#  'Deangelo',
#  'Donna',
#  'Dwight',
#  'Erin',
#  'Gabe',
#  'Holly',
#  'Jan',
#  'Jim',
#  'Jo',
#  'Josh',
#  'Karen',
#  'Katy',
#  'Kelly',
#  'Kevin',
#  'Meredith',
#  'Michael',
#  'Nellie',
#  'Oscar',
#  'Pam',
#  'Pete',
#  'Phyllis',
#  'Robert',
#  'Roy',
#  'Ryan',
#  'Stanley',
#  'Toby',
#  'Todd Packer',
#  'Val'}

# %%
top_21_speakers = set(speakers_21_df['speaker'])
# Out:
# {'Andy',
#  'Angela',
#  'Creed',
#  'Darryl',
#  'Dwight',
#  'Erin',
#  'Gabe',
#  'Holly',
#  'Jan',
#  'Jim',
#  'Kelly',
#  'Kevin',
#  'Meredith',
#  'Michael',
#  'Nellie',
#  'Oscar',
#  'Pam',
#  'Phyllis',
#  'Ryan',
#  'Stanley',
#  'Toby'}

# %%
filted_by_linecount_df = df.query('speaker in @unique_speakers_95th_percentile')
# Out:
#           id  season  episode  scene  \
# 0          1       1        1      1
# 1          2       1        1      1
# 2          3       1        1      1
# 3          4       1        1      1
# 4          5       1        1      1
# ...      ...     ...      ...    ...
# 59904  59905       9       23    112
# 59905  59906       9       23    113
# 59906  59907       9       23    114
# 59907  59908       9       23    115
# 59908  59909       9       23    116
#
#                                                                                                                                                                                                                                                                                                                    line_text  \
# 0                                                                                                                                                                                                                                             All right Jim. Your quarterlies look very good. How are things at the library?
# 1                                                                                                                                                                                                                                                                                 Oh, I told you. I couldn't close it. So...
# 2                                                                                                                                                                                                                                        So you've come to the master for guidance? Is this what you're saying, grasshopper?
# 3                                                                                                                                                                                                                                                                                 Actually, you called me in here, but yeah.
# 4                                                                                                                                                                                                                                                                            All right. Well, let me show you how it's done.
# ...                                                                                                                                                                                                                                                                                                                      ...
# 59904  It all seems so very arbitrary. I applied for a job at this company because they were hiring. I took a desk at the back because it was empty. But'[chuckles] no matter how you get there or where you end up, human beings have this miraculous gift to make that place home. [standing with two cops] Let's do this.
# 59905                                                                                                           I just feel lucky that I got a chance to share my crummy story with anyone out there who thinks they're the only one to take a dump in a paper shredder. You're not alone sister. Let's get a beer sometime.
# 59906                                                                                                                                                           I'm happy that this was all filmed so I can remember everyone and what we did. I worked for a paper company all these years and I never wrote anything down.
# 59907                                                           I sold paper at this company for 12 years. My job was to speak to clients on the phone about quantities and types of copier paper. Even if I didn't love every minute of it, everything I have, I owe to this job. This stupid,wonderful,boring,amazing job.
# 59908                                                                 I thought it was weird when you picked us to make a documentary. But all in all I think an ordinary paper company like Dunder Mifflin was a great subject for a documentary. There's a lot of beauty in ordinary things. Isn't that kind of the point?
#
#         speaker  deleted
# 0       Michael    False
# 1           Jim    False
# 2       Michael    False
# 3           Jim    False
# 4       Michael    False
# ...         ...      ...
# 59904     Creed    False
# 59905  Meredith    False
# 59906   Phyllis    False
# 59907       Jim    False
# 59908       Pam    False
#
# [55473 rows x 7 columns]

# %%
filtered_top_21_df = df.query('speaker in @top_21_speakers')
# Out:
#           id  season  episode  scene  \
# 0          1       1        1      1
# 1          2       1        1      1
# 2          3       1        1      1
# 3          4       1        1      1
# 4          5       1        1      1
# ...      ...     ...      ...    ...
# 59904  59905       9       23    112
# 59905  59906       9       23    113
# 59906  59907       9       23    114
# 59907  59908       9       23    115
# 59908  59909       9       23    116
#
#                                                                                                                                                                                                                                                                                                                    line_text  \
# 0                                                                                                                                                                                                                                             All right Jim. Your quarterlies look very good. How are things at the library?
# 1                                                                                                                                                                                                                                                                                 Oh, I told you. I couldn't close it. So...
# 2                                                                                                                                                                                                                                        So you've come to the master for guidance? Is this what you're saying, grasshopper?
# 3                                                                                                                                                                                                                                                                                 Actually, you called me in here, but yeah.
# 4                                                                                                                                                                                                                                                                            All right. Well, let me show you how it's done.
# ...                                                                                                                                                                                                                                                                                                                      ...
# 59904  It all seems so very arbitrary. I applied for a job at this company because they were hiring. I took a desk at the back because it was empty. But'[chuckles] no matter how you get there or where you end up, human beings have this miraculous gift to make that place home. [standing with two cops] Let's do this.
# 59905                                                                                                           I just feel lucky that I got a chance to share my crummy story with anyone out there who thinks they're the only one to take a dump in a paper shredder. You're not alone sister. Let's get a beer sometime.
# 59906                                                                                                                                                           I'm happy that this was all filmed so I can remember everyone and what we did. I worked for a paper company all these years and I never wrote anything down.
# 59907                                                           I sold paper at this company for 12 years. My job was to speak to clients on the phone about quantities and types of copier paper. Even if I didn't love every minute of it, everything I have, I owe to this job. This stupid,wonderful,boring,amazing job.
# 59908                                                                 I thought it was weird when you picked us to make a documentary. But all in all I think an ordinary paper company like Dunder Mifflin was a great subject for a documentary. There's a lot of beauty in ordinary things. Isn't that kind of the point?
#
#         speaker  deleted
# 0       Michael    False
# 1           Jim    False
# 2       Michael    False
# 3           Jim    False
# 4       Michael    False
# ...         ...      ...
# 59904     Creed    False
# 59905  Meredith    False
# 59906   Phyllis    False
# 59907       Jim    False
# 59908       Pam    False
#
# [52207 rows x 7 columns]

# %%
len(df) - len(filted_by_linecount_df)
# Out:
# 4436

# %%
filted_by_linecount_df.reset_index()
# Out:
#        index     id  season  episode  scene  \
# 0          0      1       1        1      1
# 1          1      2       1        1      1
# 2          2      3       1        1      1
# 3          3      4       1        1      1
# 4          4      5       1        1      1
# ...      ...    ...     ...      ...    ...
# 55468  59904  59905       9       23    112
# 55469  59905  59906       9       23    113
# 55470  59906  59907       9       23    114
# 55471  59907  59908       9       23    115
# 55472  59908  59909       9       23    116
#
#                                                                                                                                                                                                                                                                                                                    line_text  \
# 0                                                                                                                                                                                                                                             All right Jim. Your quarterlies look very good. How are things at the library?
# 1                                                                                                                                                                                                                                                                                 Oh, I told you. I couldn't close it. So...
# 2                                                                                                                                                                                                                                        So you've come to the master for guidance? Is this what you're saying, grasshopper?
# 3                                                                                                                                                                                                                                                                                 Actually, you called me in here, but yeah.
# 4                                                                                                                                                                                                                                                                            All right. Well, let me show you how it's done.
# ...                                                                                                                                                                                                                                                                                                                      ...
# 55468  It all seems so very arbitrary. I applied for a job at this company because they were hiring. I took a desk at the back because it was empty. But'[chuckles] no matter how you get there or where you end up, human beings have this miraculous gift to make that place home. [standing with two cops] Let's do this.
# 55469                                                                                                           I just feel lucky that I got a chance to share my crummy story with anyone out there who thinks they're the only one to take a dump in a paper shredder. You're not alone sister. Let's get a beer sometime.
# 55470                                                                                                                                                           I'm happy that this was all filmed so I can remember everyone and what we did. I worked for a paper company all these years and I never wrote anything down.
# 55471                                                           I sold paper at this company for 12 years. My job was to speak to clients on the phone about quantities and types of copier paper. Even if I didn't love every minute of it, everything I have, I owe to this job. This stupid,wonderful,boring,amazing job.
# 55472                                                                 I thought it was weird when you picked us to make a documentary. But all in all I think an ordinary paper company like Dunder Mifflin was a great subject for a documentary. There's a lot of beauty in ordinary things. Isn't that kind of the point?
#
#         speaker  deleted
# 0       Michael    False
# 1           Jim    False
# 2       Michael    False
# 3           Jim    False
# 4       Michael    False
# ...         ...      ...
# 55468     Creed    False
# 55469  Meredith    False
# 55470   Phyllis    False
# 55471       Jim    False
# 55472       Pam    False
#
# [55473 rows x 8 columns]

# %%
filtered_top_21_df.reset_index()
# Out:
#        index     id  season  episode  scene  \
# 0          0      1       1        1      1
# 1          1      2       1        1      1
# 2          2      3       1        1      1
# 3          3      4       1        1      1
# 4          4      5       1        1      1
# ...      ...    ...     ...      ...    ...
# 52202  59904  59905       9       23    112
# 52203  59905  59906       9       23    113
# 52204  59906  59907       9       23    114
# 52205  59907  59908       9       23    115
# 52206  59908  59909       9       23    116
#
#                                                                                                                                                                                                                                                                                                                    line_text  \
# 0                                                                                                                                                                                                                                             All right Jim. Your quarterlies look very good. How are things at the library?
# 1                                                                                                                                                                                                                                                                                 Oh, I told you. I couldn't close it. So...
# 2                                                                                                                                                                                                                                        So you've come to the master for guidance? Is this what you're saying, grasshopper?
# 3                                                                                                                                                                                                                                                                                 Actually, you called me in here, but yeah.
# 4                                                                                                                                                                                                                                                                            All right. Well, let me show you how it's done.
# ...                                                                                                                                                                                                                                                                                                                      ...
# 52202  It all seems so very arbitrary. I applied for a job at this company because they were hiring. I took a desk at the back because it was empty. But'[chuckles] no matter how you get there or where you end up, human beings have this miraculous gift to make that place home. [standing with two cops] Let's do this.
# 52203                                                                                                           I just feel lucky that I got a chance to share my crummy story with anyone out there who thinks they're the only one to take a dump in a paper shredder. You're not alone sister. Let's get a beer sometime.
# 52204                                                                                                                                                           I'm happy that this was all filmed so I can remember everyone and what we did. I worked for a paper company all these years and I never wrote anything down.
# 52205                                                           I sold paper at this company for 12 years. My job was to speak to clients on the phone about quantities and types of copier paper. Even if I didn't love every minute of it, everything I have, I owe to this job. This stupid,wonderful,boring,amazing job.
# 52206                                                                 I thought it was weird when you picked us to make a documentary. But all in all I think an ordinary paper company like Dunder Mifflin was a great subject for a documentary. There's a lot of beauty in ordinary things. Isn't that kind of the point?
#
#         speaker  deleted
# 0       Michael    False
# 1           Jim    False
# 2       Michael    False
# 3           Jim    False
# 4       Michael    False
# ...         ...      ...
# 52202     Creed    False
# 52203  Meredith    False
# 52204   Phyllis    False
# 52205       Jim    False
# 52206       Pam    False
#
# [52207 rows x 8 columns]

# %%
del filted_by_linecount_df['id']
filted_by_linecount_df
# Out:
#        season  episode  scene  \
# 0           1        1      1
# 1           1        1      1
# 2           1        1      1
# 3           1        1      1
# 4           1        1      1
# ...       ...      ...    ...
# 59904       9       23    112
# 59905       9       23    113
# 59906       9       23    114
# 59907       9       23    115
# 59908       9       23    116
#
#                                                                                                                                                                                                                                                                                                                    line_text  \
# 0                                                                                                                                                                                                                                             All right Jim. Your quarterlies look very good. How are things at the library?
# 1                                                                                                                                                                                                                                                                                 Oh, I told you. I couldn't close it. So...
# 2                                                                                                                                                                                                                                        So you've come to the master for guidance? Is this what you're saying, grasshopper?
# 3                                                                                                                                                                                                                                                                                 Actually, you called me in here, but yeah.
# 4                                                                                                                                                                                                                                                                            All right. Well, let me show you how it's done.
# ...                                                                                                                                                                                                                                                                                                                      ...
# 59904  It all seems so very arbitrary. I applied for a job at this company because they were hiring. I took a desk at the back because it was empty. But'[chuckles] no matter how you get there or where you end up, human beings have this miraculous gift to make that place home. [standing with two cops] Let's do this.
# 59905                                                                                                           I just feel lucky that I got a chance to share my crummy story with anyone out there who thinks they're the only one to take a dump in a paper shredder. You're not alone sister. Let's get a beer sometime.
# 59906                                                                                                                                                           I'm happy that this was all filmed so I can remember everyone and what we did. I worked for a paper company all these years and I never wrote anything down.
# 59907                                                           I sold paper at this company for 12 years. My job was to speak to clients on the phone about quantities and types of copier paper. Even if I didn't love every minute of it, everything I have, I owe to this job. This stupid,wonderful,boring,amazing job.
# 59908                                                                 I thought it was weird when you picked us to make a documentary. But all in all I think an ordinary paper company like Dunder Mifflin was a great subject for a documentary. There's a lot of beauty in ordinary things. Isn't that kind of the point?
#
#         speaker  deleted
# 0       Michael    False
# 1           Jim    False
# 2       Michael    False
# 3           Jim    False
# 4       Michael    False
# ...         ...      ...
# 59904     Creed    False
# 59905  Meredith    False
# 59906   Phyllis    False
# 59907       Jim    False
# 59908       Pam    False
#
# [55473 rows x 6 columns]

# %%
del filtered_top_21_df['id']
filtered_top_21_df
# Out:
#        season  episode  scene  \
# 0           1        1      1
# 1           1        1      1
# 2           1        1      1
# 3           1        1      1
# 4           1        1      1
# ...       ...      ...    ...
# 59904       9       23    112
# 59905       9       23    113
# 59906       9       23    114
# 59907       9       23    115
# 59908       9       23    116
#
#                                                                                                                                                                                                                                                                                                                    line_text  \
# 0                                                                                                                                                                                                                                             All right Jim. Your quarterlies look very good. How are things at the library?
# 1                                                                                                                                                                                                                                                                                 Oh, I told you. I couldn't close it. So...
# 2                                                                                                                                                                                                                                        So you've come to the master for guidance? Is this what you're saying, grasshopper?
# 3                                                                                                                                                                                                                                                                                 Actually, you called me in here, but yeah.
# 4                                                                                                                                                                                                                                                                            All right. Well, let me show you how it's done.
# ...                                                                                                                                                                                                                                                                                                                      ...
# 59904  It all seems so very arbitrary. I applied for a job at this company because they were hiring. I took a desk at the back because it was empty. But'[chuckles] no matter how you get there or where you end up, human beings have this miraculous gift to make that place home. [standing with two cops] Let's do this.
# 59905                                                                                                           I just feel lucky that I got a chance to share my crummy story with anyone out there who thinks they're the only one to take a dump in a paper shredder. You're not alone sister. Let's get a beer sometime.
# 59906                                                                                                                                                           I'm happy that this was all filmed so I can remember everyone and what we did. I worked for a paper company all these years and I never wrote anything down.
# 59907                                                           I sold paper at this company for 12 years. My job was to speak to clients on the phone about quantities and types of copier paper. Even if I didn't love every minute of it, everything I have, I owe to this job. This stupid,wonderful,boring,amazing job.
# 59908                                                                 I thought it was weird when you picked us to make a documentary. But all in all I think an ordinary paper company like Dunder Mifflin was a great subject for a documentary. There's a lot of beauty in ordinary things. Isn't that kind of the point?
#
#         speaker  deleted
# 0       Michael    False
# 1           Jim    False
# 2       Michael    False
# 3           Jim    False
# 4       Michael    False
# ...         ...      ...
# 59904     Creed    False
# 59905  Meredith    False
# 59906   Phyllis    False
# 59907       Jim    False
# 59908       Pam    False
#
# [52207 rows x 6 columns]

# %%
filtered_file_path = Path('../data/filtered_95th_percentile_dialog.csv')

if not filtered_file_path.is_file():
    filted_by_linecount_df.to_csv(filtered_file_path, index=False, encoding='utf-8')

# %%
filtered_top_21_path = Path('../data/filtered_top_21_dialog.csv')

if not filtered_top_21_path.is_file():
    filtered_top_21_df.to_csv(filtered_top_21_path, index=False, encoding='utf-8')
